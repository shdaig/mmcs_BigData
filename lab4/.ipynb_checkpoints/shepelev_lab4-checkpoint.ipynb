# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
# Out:
# 2023-04-24 01:15:49.430034: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 01:15:50.034723: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:
# 2023-04-24 01:15:50.034795: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:
# 2023-04-24 01:15:50.034814: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # **Подгрузка данные**

# %%
df = pd.read_csv("weather_extended.csv")
df
# Out:
#                        date  temperature  pressure  humidity  sunshine
# 0       2022-01-01 00:00:00        -21.9     765.6      83.0      7.07
# 1       2022-01-01 00:30:00        -22.1     765.6      84.0      7.07
# 2       2022-01-01 01:00:00        -22.1     765.6      84.0      7.07
# 3       2022-01-01 01:30:00        -22.3     765.7      84.0      7.07
# 4       2022-01-01 02:00:00        -22.2     765.7      84.0      7.07
# ...                     ...          ...       ...       ...       ...
# 122635  2028-12-29 21:30:00        -22.3     765.7      84.0      7.07
# 122636  2028-12-29 22:00:00        -22.6     765.8      84.0      7.07
# 122637  2028-12-29 22:30:00        -22.7     765.8      84.0      7.07
# 122638  2028-12-29 23:00:00        -22.8     765.8      84.0      7.07
# 122639  2028-12-29 23:30:00        -22.9     765.9      84.0      7.07
#
# [122640 rows x 5 columns]

# %% [markdown]
# # **Функция организации временных интервалов**

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
        
    return np.array(data), np.array(labels)

# %% [markdown]
# **Первые 105 120 строк данных будут использоваться для обучения модели, оставшиеся – для её валидации**

# %%
TRAIN_SPLIT = 105120

# %% [markdown]
# **Для обеспечения воспроизводимости результатов устанавливается функция seed**

# %%
tf.random.set_seed(42)

# %% [markdown]
# # **Прогнозирование на основе одномерного временного ряда**

# %% [markdown]
# Извлечем только температуру из набора данных

# %%
uni_data = df['temperature']
uni_data.index = df['date']
uni_data
# Out:
# date
# 2022-01-01 00:00:00   -21.9
# 2022-01-01 00:30:00   -22.1
# 2022-01-01 01:00:00   -22.1
# 2022-01-01 01:30:00   -22.3
# 2022-01-01 02:00:00   -22.2
#                        ...
# 2028-12-29 21:30:00   -22.3
# 2028-12-29 22:00:00   -22.6
# 2028-12-29 22:30:00   -22.7
# 2028-12-29 23:00:00   -22.8
# 2028-12-29 23:30:00   -22.9
# Name: temperature, Length: 122640, dtype: float64

# %% [markdown]
# Отобразим данные на графике

# %%
uni_data.plot(subplots=True)
# Out:
# array([<AxesSubplot: xlabel='date'>], dtype=object)

# %%
uni_data = uni_data.values

# %% [markdown]
# Маштабирование данных.
#
# Выполним стандартизацию набора данных с вычислением среднего значения и стандартного отклонения обучающих данных

# %%
uni_train_mean = uni_data[:TRAIN_SPLIT].mean()
uni_train_std = uni_data[:TRAIN_SPLIT].std()

# %% [markdown]
# Выполним стандартизацию данных

# %%
uni_data = (uni_data - uni_train_mean) / uni_train_std

# %% [markdown]
# Далее подготовим данные для модели с одномерным входом.

# %% [markdown]
# На вход в модель будут подаваться последние 20 наблюдений за температурой, и модель необходимо обучить прогнозировать температуру на следующем шаге.

# %%
univariate_past_history = 20
univariate_future_target = 0
# Тестовая
x_train_uni, y_train_uni = univariate_data(uni_data, 0, TRAIN_SPLIT, univariate_past_history, univariate_future_target)
# Валидационая
x_val_uni, y_val_uni = univariate_data(uni_data, TRAIN_SPLIT, None, univariate_past_history, univariate_future_target)

# %% [markdown]
# Результаты применения функции `univariate_data`

# %%
print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target temperature to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-1.40459411]
#  [-1.41869833]
#  [-1.41869833]
#  [-1.43280254]
#  [-1.42575044]
#  [-1.43985465]
#  [-1.43985465]
#  [-1.43280254]
#  [-1.43985465]
#  [-1.43280254]
#  [-1.42575044]
#  [-1.42575044]
#  [-1.41869833]
#  [-1.41869833]
#  [-1.40459411]
#  [-1.397542  ]
#  [-1.39048989]
#  [-1.37638567]
#  [-1.37638567]
#  [-1.36228146]]
#
#  Target temperature to predict
# -1.3552293475049326

# %% [markdown]
# Представим данные в виде графика

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
# Out:
# <module 'matplotlib.pyplot' from '/home/danil/Projects/Python/environments/p310-env/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # **Рекуррентная нейронная сеть**
#
# LSTM «Долгая краткосрочная память»

# %%
BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
# Out:
# 2023-04-24 01:16:01.261807: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:01.313042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:01.313513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:01.317127: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 01:16:01.319076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:01.319461: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:01.319820: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:02.335010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:02.335748: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:02.335984: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 01:16:02.336444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2609 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

# %% [markdown]
# Проверим выход модели

# %%
for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)
# Out:
# 2023-04-24 01:16:05.847031: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8101
# 8/8 [==============================] - 2s 2ms/step
# (256, 1)

# %% [markdown]
# Обучением модели

# %%
EVALUATION_INTERVAL = 400
EPOCHS = 20

simple_lstm_model.fit(train_univariate, epochs=EPOCHS, steps_per_epoch=EVALUATION_INTERVAL, validation_data=val_univariate, validation_steps=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 EVALUATION_INTERVAL = 200
#       2 EPOCHS = 20
# ----> 4 simple_lstm_model.fit(train_univariate, epochs=EPOCHS, validation_data=val_univariate, validation_steps=50)
#
# File ~/Projects/Python/environments/p310-env/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Projects/Python/environments/p310-env/lib/python3.10/site-packages/keras/engine/data_adapter.py:818, in DatasetAdapter._validate_args(self, y, sample_weights, steps)
#     813 size = tf.data.experimental.cardinality(self._dataset).numpy()
#     814 if (
#     815     size == tf.data.experimental.INFINITE_CARDINALITY
#     816     and steps is None
#     817 ):
# --> 818     raise ValueError(
#     819         "When providing an infinite dataset, you must specify "
#     820         "the number of steps to run (if you did not intend to "
#     821         "create an infinite dataset, make sure to not call "
#     822         "`repeat()` on the dataset)."
#     823     )
#
# ValueError: When providing an infinite dataset, you must specify the number of steps to run (if you did not intend to create an infinite dataset, make sure to not call `repeat()` on the dataset).

# %% [markdown]
# Выполним несколько прогнозов

# %%
for x, y in val_univariate.take(3):
    plot = show_plot([x[0].numpy(), y[0].numpy(), simple_lstm_model.predict(x)[0]], 0, 'Simple LSTM model')
    plot.show()
# Out:
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 1ms/step

# %% [markdown]
# # **Прогнозирование на основе многомерного временного ряда**

# %% [markdown]
# Извлечем давление, температуру и плотность воздуха из набора данных

# %%
features = df[['temperature', 'pressure', 'humidity']]
features.index = df['date']
features.head()
# Out:
#                      temperature  pressure  humidity
# date
# 2022-01-01 00:00:00        -21.9     765.6      83.0
# 2022-01-01 00:30:00        -22.1     765.6      84.0
# 2022-01-01 01:00:00        -22.1     765.6      84.0
# 2022-01-01 01:30:00        -22.3     765.7      84.0
# 2022-01-01 02:00:00        -22.2     765.7      84.0

# %% [markdown]
# Отобразим данные на графике

# %%
features.plot(subplots=True)
# Out:
# array([<AxesSubplot: xlabel='date'>, <AxesSubplot: xlabel='date'>,
#        <AxesSubplot: xlabel='date'>], dtype=object)

# %% [markdown]
# Маштабирование данных.
#
# Выполним стандартизацию набора данных с вычислением среднего значения и стандартного отклонения обучающих данных

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)

# %% [markdown]
# Выполним стандартизацию данных

# %%
dataset = (dataset - data_mean) / data_std

# %% [markdown]
# # **Точечное прогнозирование**

# %% [markdown]
# **Функция организации временных интервалов**

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %% [markdown]
# В данном наборе данные за последние пять суток (2 х 24 х 5 = 240). Допустим, что отбор данных проводится не каждые 30 минут, а каждый час: в течение 60 минут резкие изменения не ожидаются. Следовательно, историю последних пяти дней составляют 120 наблюдений (240/2). Для модели, выполняющей точечное прогнозирование, целью является значение температуры через 12 часов в будущем. В этом случае целевой вектор будет составлять температура после 24 (12х2) наблюдений.

# %%
past_history = 240
future_target = 24
STEP = 2

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0, TRAIN_SPLIT, past_history, future_target, STEP, single_step=True)

x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1], TRAIN_SPLIT, None, past_history, future_target, STEP, single_step=True)

# %% [markdown]
# Результаты применения функции `multivariate_data`

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (120, 3)

# %% [markdown]
# **Рекуррентная нейронная сеть**

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %% [markdown]
# Проверим нашу выборку и выведем кривые потерь на этапах обучения и проверки

# %%
for x, y in val_data_single.take(1):
      print(single_step_model.predict(x).shape)
# Out:
# 8/8 [==============================] - 0s 2ms/step
# (256, 1)

# %%
EPOCHS = 20

# %% [markdown]
# Обучением модели

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS, steps_per_epoch=EVALUATION_INTERVAL, validation_data=val_data_single, validation_steps=50)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 2s 7ms/step - loss: 0.0924 - val_loss: 0.0634
# Epoch 2/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0540 - val_loss: 0.0411
# Epoch 3/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0436 - val_loss: 0.0354
# Epoch 4/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0412 - val_loss: 0.0402
# Epoch 5/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0400 - val_loss: 0.0375
# Epoch 6/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0392 - val_loss: 0.0421
# Epoch 7/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0382 - val_loss: 0.0390
# Epoch 8/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0374 - val_loss: 0.0366
# Epoch 9/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0365 - val_loss: 0.0334
# Epoch 10/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.0350
# Epoch 11/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0308
# Epoch 12/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0330
# Epoch 13/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0348 - val_loss: 0.0430
# Epoch 14/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0347 - val_loss: 0.0331
# Epoch 15/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0344 - val_loss: 0.0315
# Epoch 16/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.0299
# Epoch 17/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0338 - val_loss: 0.0321
# Epoch 18/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0337 - val_loss: 0.0317
# Epoch 19/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0330 - val_loss: 0.0342
# Epoch 20/20
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0332 - val_loss: 0.0314

# %% [markdown]
# Выведим график потерь

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(single_step_history, 'Single Step Training and validation loss')

# %% [markdown]
# **Выполнение точечного прогноза**

# %% [markdown]
# Выполним несколько прогнозов

# %%
for x, y in val_data_single.take(3):
    plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(), single_step_model.predict(x)[0]], 12, 'Single Step Prediction')
    plot.show()
# Out:
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step

# %% [markdown]
# **Интервальное прогнозирование**

# %%
future_target = 24
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0, TRAIN_SPLIT, past_history, future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1], TRAIN_SPLIT, None, past_history, future_target, STEP)

# %% [markdown]
# Проверим выборку

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (120, 3)
#
#  Target temperature to predict : (24,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# Подготовим визуализацию

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(12, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 1]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# На этом и последующих аналогичных графиках история и будущие данные ежечасные

# %%
for x, y in train_data_multi.take(1):
    multi_step_plot(x[0], y[0], np.array([0]))
# Out:
# 2023-04-23 17:11:46.052689: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# Так как эта задача немного сложнее, чем предыдущая, то модель будет состоять из двух слоёв LSTM. Наконец, поскольку выполняется 24 прогноза, выход слой насчитывает 24 нейрона.

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16))
multi_step_model.add(tf.keras.layers.Dense(24))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %% [markdown]
# Проверим нашу выборку и выведем кривые потерь на этапах обучения и проверки

# %%
for x, y in val_data_multi.take(1):
    print (multi_step_model.predict(x).shape)
# Out:
# 8/8 [==============================] - 0s 3ms/step
# (256, 24)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS, steps_per_epoch=EVALUATION_INTERVAL, validation_data=val_data_multi, validation_steps=50)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 4s 11ms/step - loss: 0.2367 - val_loss: 0.0842
# Epoch 2/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0637 - val_loss: 0.0644
# Epoch 3/20
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0601 - val_loss: 0.0606
# Epoch 4/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0574 - val_loss: 0.0554
# Epoch 5/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0535 - val_loss: 0.0485
# Epoch 6/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0489 - val_loss: 0.0492
# Epoch 7/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0449 - val_loss: 0.0507
# Epoch 8/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0420 - val_loss: 0.0475
# Epoch 9/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0395 - val_loss: 0.0377
# Epoch 10/20
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0380 - val_loss: 0.0370
# Epoch 11/20
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0368 - val_loss: 0.0346
# Epoch 12/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0357 - val_loss: 0.0337
# Epoch 13/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0346 - val_loss: 0.0324
# Epoch 14/20
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0341 - val_loss: 0.0382
# Epoch 15/20
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0332 - val_loss: 0.0290
# Epoch 16/20
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0328 - val_loss: 0.0278
# Epoch 17/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0320 - val_loss: 0.0253
# Epoch 18/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0316 - val_loss: 0.0282
# Epoch 19/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0309 - val_loss: 0.0287
# Epoch 20/20
# 200/200 [==============================] - 2s 8ms/step - loss: 0.0305 - val_loss: 0.0340

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %% [markdown]
# **Выполнение интервального прогноза**

# %% [markdown]
# Прогноз будущих значений температуры

# %%
for x, y in val_data_multi.take(3):
    multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
# Out:
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
